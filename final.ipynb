# %%
import pandas as pd

# %%
results=pd.read_pickle("final_results")

# %%
results
# Out:
#     item_id                                   extracted answer  \
# 0   1634266                                      FL240 - FL220
# 1   1546512                                    third touchdown
# 2   1021514                                          Runway 26
# 3   1214912  The aircraft was out of communication and flew...
# 4   1300807                                    training flight
# 5   1443017  PRB airport was IFR for longer than normal res...
# 6   1069350                                    Before boarding
# 7   1583082  When the customer arrived to pick up the bag, ...
# 8   1345107  Departed VFR, remained under Class Charlie unt...
# 9   1427131                                 during runway exit
# 10  1623276  the initial part of the arrival in mild turbul...
# 11  1353948  roughly 200 ft south of that runway, [results ...
# 12  1091351                                      After takeoff
# 13  1474684                                          10,000 ft
# ...

# %% [raw]
# results.to_pickle("final_results")

# %% [raw]
# results.sort_values(["group"]).reset_index(drop=True).to_pickle("final_results")asrs time to process report
